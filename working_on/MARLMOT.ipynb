# %% [markdown]
# <a href="https://colab.research.google.com/github/itberrios/CV_tracking/blob/main/MARLMOT/MARLMOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MARLMOT**
#
# This notebook contains a basic MARLMOT implementation. The base tracker will be SORT and Multi-Agent Policy Parameterized by a Neural Network will be used to manage each track.
#
# The Policy will be trained on the MOT 2015 challenge

# %%
# !wget https://motchallenge.net/data/MOT15.zip
# Out:
# --2024-04-09 16:20:38--  https://motchallenge.net/data/MOT15.zip
# Resolving motchallenge.net (motchallenge.net)... 2a09:80c0:18::1034, 131.159.19.34
# Connecting to motchallenge.net (motchallenge.net)|2a09:80c0:18::1034|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1310994213 (1.2G) [application/zip]
# Saving to: ‘MOT15.zip’
#
# MOT15.zip           100%[===================>]   1.22G  17.0MB/s    in 70s
#
# 2024-04-09 16:21:48 (18.0 MB/s) - ‘MOT15.zip’ saved [1310994213/1310994213]

# %%
# !jar xf MOT15.zip
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports jar.
# Please visit http://www.java.com for information on installing Java.

# %%
import os
from glob import glob
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams["figure.figsize"] = (20, 10)

# %%
TRAIN_FOLDERS = r"MOT15/train"
TRAIN_NAMES = next(iter(os.walk(TRAIN_FOLDERS)))[1]
TRAIN_NAMES
# Out:
# ['ETH-Bahnhof',
#  'ADL-Rundle-8',
#  'ADL-Rundle-6',
#  'ETH-Pedcross2',
#  'TUD-Stadtmitte',
#  'TUD-Campus',
#  'KITTI-17',
#  'PETS09-S2L1',
#  'Venice-2',
#  'ETH-Sunnyday',
#  'KITTI-13']

# %%
GT_COLS = ["frame", "id", "bb_left", "bb_top", "bb_width", "bb_height"]

# %%
train_folder = os.path.join(TRAIN_FOLDERS, TRAIN_NAMES[0])
gt = pd.read_csv(os.path.join(train_folder, "gt/gt.txt"), usecols=[0,1,2,3,4,5], 
                 header=None)
gt.columns = GT_COLS
gt.head()
# Out:
#    frame  id  bb_left  bb_top  bb_width  bb_height
# 0      1   1      212     204        20         57
# 1      1   2      223     181        36        104
# 2      1   3      293     151        61        174
# 3      1   4      452     208        27         68
# 4      1   5      255     219        13         30

# %%
def get_color(idx):
    """ Converts an index to a color
        """
    blue = idx*30 % 256
    green = idx*103 % 256
    red = idx*50 % 256
    return (red, green, blue)

# %%
train_images = sorted(glob(os.path.join(train_folder, "**/*.jpg")))

# get current frame
idx = 0
current_tracks = gt.loc[gt.frame == (idx + 1), :]
frame = cv2.cvtColor(cv2.imread(train_images[idx]), cv2.COLOR_BGR2RGB)

# draw ground truth on frame
for id in current_tracks.id:
    track = current_tracks[current_tracks.id == id]

    color = get_color(id)

    pt1 = track.iloc[0, 2:4].to_numpy().astype(int)
    pt2 = pt1 + track.iloc[0, 4:6].to_numpy().round().astype(int)
    frame = cv2.rectangle(frame, pt1, pt2, color, 2)


# display frame
plt.imshow(frame)

# %% [markdown]
# ###Get YOLOv8

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -r requirements.txt
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 24009, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 24009 (delta 21), reused 18 (delta 7), pack-reused 23966
# Receiving objects: 100% (24009/24009), 14.18 MiB | 19.01 MiB/s, done.
# Resolving deltas: 100% (16897/16897), done.
# /Users/fpfp2/Desktop/Masters Thesis/CV_tracking/MARLMOT/ultralytics
# /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# %cd ..
# !pip install ultralytics
# Out:
# /Users/fpfp2/Desktop/Masters Thesis/CV_tracking/MARLMOT
# Requirement already satisfied: ultralytics in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (8.1.45)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (5.9.2)
# Requirement already satisfied: py-cpuinfo in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: six>=1.5 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
# !pip install filterpy
# Out:
# Requirement already satisfied: filterpy in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (1.4.5)
# Requirement already satisfied: numpy in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from filterpy) (1.26.4)
# Requirement already satisfied: scipy in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from filterpy) (1.12.0)
# Requirement already satisfied: matplotlib in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from filterpy) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from matplotlib->filterpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/fpfp2/opt/anaconda3/envs/RodTracker/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->filterpy) (1.16.0)

# %% [markdown]
# import SORT

# %%
# !wget https://raw.githubusercontent.com/itberrios/CV_tracking/main/SORT/sort.py
# !wget https://raw.githubusercontent.com/abewley/sort/master/sort.py # OG SORT
from sort import *
# Out:
# --2024-04-09 16:23:49--  https://raw.githubusercontent.com/itberrios/CV_tracking/main/SORT/sort.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8000::154, 2606:50c0:8001::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8000::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9962 (9.7K) [text/plain]
# Saving to: ‘sort.py’
#
# sort.py             100%[===================>]   9.73K  --.-KB/s    in 0s
#
# 2024-04-09 16:23:50 (19.9 MB/s) - ‘sort.py’ saved [9962/9962]

# %% [markdown]
# Import YOLO model and define detection function

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 21.3MB/s]

# %%
def get_detections(model, frame, conf=0.25):
    """ Obtains object detections from a single frame
        Inputs:
            model - YOLOv8 model object
            frame - RGB frame for detection
        Outputs:
            detections - array containing all detections and classes
                [[x1,y1,x2,y2,cls],...]
        NOTE: can modify this to obtain detections for batches of frames
        """
    # can also process multiple frames at once
    results = model(source=frame, stream=True, conf=conf, nms=True, 
                    iou=0.5, verbose=False)

    for result in results:
        xyxy = result.boxes.xyxy.cpu().numpy()
        cls = result.boxes.cls.cpu().numpy()
        conf_score = result.boxes.conf.cpu().numpy()

    return np.hstack((xyxy, np.c_[cls], np.c_[conf_score]))

# %% [markdown]
# Get MSCOCO classes

# %%
# !ls
# Out:
# MARLMOT.ipynb                network.py
# MOT15                        ppo.py
# MOT15.zip                    sort.py
# README.md                    test_world.py
# __pycache__                  track_utils.py
# dataloader.py                train.py
# eval.py                      train_world.py
# inference.py                 trained_models
# interactive_model_eval.ipynb ultralytics
# interactive_train_eval.ipynb yolov8n.pt

# %%
import yaml

coco_fp = r"ultralytics/ultralytics/cfg/datasets/coco.yaml"
with open(coco_fp, "r") as stream:
    try:
        coco_info = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# get classes dictionary
classes = coco_info['names']

# %% [markdown]
# Run tracker on frames

# %%
tracker = Sort(max_age=3, min_hits=1, iou_threshold=0.3)


result_frames = []
all_detections = []
all_tracks = []
for fpath in train_images:
    frame = cv2.cvtColor(cv2.imread(fpath), cv2.COLOR_BGR2RGB)
    detections = get_detections(model, frame)

    # don't send confidence to the tracker
    current_tracks = tracker.update(detections[:, :5].astype(int))
    all_detections.append(detections)
    all_tracks.append(current_tracks)

    # draw track info on frames
    for trk in current_tracks:
        pt1 = trk[0:2].astype(int)
        pt2 = trk[2:4].astype(int)

        # get color from track id (it looks better this way)
        color = get_color(trk[4])
        # class and track id
        label = str(classes[int(trk[5])] + '_' + str(int(trk[4])))

        frame = cv2.rectangle(frame, pt1, pt2, color, 2)
        frame = cv2.putText(frame, label, (pt1 + 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, 
                            color, thickness=2)

    # save results
    result_frames.append(frame)
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
detections = get_detections(model, frame)
detections
# Out:
# array([[     575.26,      234.43,      637.49,      317.89,           1,     0.87774],
#        [     235.59,      204.05,      255.75,      278.09,           0,     0.53305],
#        [      214.7,      211.68,       231.7,       268.8,           0,     0.28557],
#        [      281.3,      205.67,      301.36,      260.24,           0,     0.26029]], dtype=float32)

# %%
all_tracks[0]
# Out:
# array([[        541,         216,         554,         248,           7,           0],
#        [        211,         201,         226,         255,           6,           0],
#        [        269,         210,         284,         246,           5,           0],
#        [        587,         211,         602,         246,           4,           0],
#        [        455,         208,         483,         274,           3,           0],
#        [        224,         185,         256,         282,           2,           0],
#        [        293,         150,         351,         321,           1,           0]])

# %%
frame_tracks = all_tracks[100] 
frame_tracks = np.round(frame_tracks[frame_tracks[:,-1] == 0][:, :4]).astype(int) # only get bboxes of person tracks
frame_tracks
# Out:
# array([[418, 198, 443, 286],
#        [546, 160, 621, 377],
#        [302, 218, 318, 267],
#        [397, 200, 422, 285],
#        [439, 139, 537, 382],
#        [256, 206, 278, 278],
#        [286, 220, 300, 262],
#        [319, 220, 336, 268],
#        [229, 206, 250, 271]])

# %%
plt.imshow(result_frames[100])

# %%
# get current frame
idx = 100
current_tracks = gt.loc[gt.frame == (idx + 1), :]
frame = cv2.cvtColor(cv2.imread(train_images[idx]), cv2.COLOR_BGR2RGB)

gt_bbox = []

# draw ground truth on frame
for id in current_tracks.id:
    track = current_tracks[current_tracks.id == id]

    color = get_color(id)

    pt1 = track.iloc[0, 2:4].to_numpy().astype(int)
    pt2 = pt1 + track.iloc[0, 4:6].to_numpy().round().astype(int)
    frame = cv2.rectangle(frame, pt1, pt2, color, 2)

    cv2.circle(frame, pt1, 5, color, -1)

    frame = cv2.putText(frame, str(pt1), (pt1 + 30), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, 
                        color, thickness=2)

    # print(pt1, pt2)
    gt_bbox.append([pt1[0], pt1[1], pt2[0], pt2[1]])


# convert to array
gt_bbox = np.array(gt_bbox)

# display frame
plt.imshow(frame)

# %% [markdown]
# Compare Ground Truth to Tracklets

# %%
gt_bbox
# Out:
# array([[255, 209, 280, 283],
#        [439, 131, 541, 383],
#        [544, 158, 625, 377],
#        [229, 203, 257, 273],
#        [287, 216, 304, 264],
#        [299, 211, 321, 269],
#        [316, 216, 340, 269],
#        [395, 201, 424, 288],
#        [418, 197, 446, 286]])

# %%
frame_tracks
# Out:
# array([[418, 198, 443, 286],
#        [546, 160, 621, 377],
#        [302, 218, 318, 267],
#        [397, 200, 422, 285],
#        [439, 139, 537, 382],
#        [256, 206, 278, 278],
#        [286, 220, 300, 262],
#        [319, 220, 336, 268],
#        [229, 206, 250, 271]])

# %% [markdown]
# Perform Hungarian Matching on tracks from tracker and Ground Truth

# %%
matches, false_positives, missed_tracks = \
            associate(gt_bbox, frame_tracks, thresh=1e-6)

# %%
matches
# Out:
# array([[0, 5],
#        [1, 4],
#        [2, 1],
#        [3, 8],
#        [4, 6],
#        [5, 2],
#        [6, 7],
#        [7, 3],
#        [8, 0]])

# %%
false_positives
# Out:
# []

# %%
missed_tracks
# Out:
# []

# %% [markdown]
# Save all tracks for future usage

# %%
frame_arr = np.arange(0, len(all_tracks))

# %%
all_tracks[0]
# Out:
# array([[        541,         216,         554,         248,           7,           0],
#        [        211,         201,         226,         255,           6,           0],
#        [        269,         210,         284,         246,           5,           0],
#        [        587,         211,         602,         246,           4,           0],
#        [        455,         208,         483,         274,           3,           0],
#        [        224,         185,         256,         282,           2,           0],
#        [        293,         150,         351,         321,           1,           0]])

# %%
all_tracks_2 = []

for i in range(len(all_tracks)):
    all_tracks_2.append(np.hstack((np.ones((len(all_tracks[i]), 1))*i, all_tracks[i])))

# %%
df = pd.DataFrame(np.vstack(all_tracks_2))
df.columns = ["frame", "x1", "y1", "x2", "y2", "id", "cat"]
df.head()
# Out:
#    frame     x1     y1     x2     y2   id  cat
# 0    0.0  541.0  216.0  554.0  248.0  7.0  0.0
# 1    0.0  211.0  201.0  226.0  255.0  6.0  0.0
# 2    0.0  269.0  210.0  284.0  246.0  5.0  0.0
# 3    0.0  587.0  211.0  602.0  246.0  4.0  0.0
# 4    0.0  455.0  208.0  483.0  274.0  3.0  0.0

# %%
train_images[0]
# Out:
# 'MOT15/train/ETH-Bahnhof/img1/000001.jpg'

# %%
df.to_csv("ADL-Rundle-6_SORT_tracks.csv")

# %%
all_detections[0]
# Out:
# array([[     293.08,      150.64,      351.45,      321.15,           0,     0.90558],
#        [      224.2,      185.92,      256.63,      282.38,           0,     0.84266],
#        [     455.39,      208.81,         483,      274.61,           0,     0.75515],
#        [     587.26,      211.74,       602.7,      246.68,           0,     0.50708],
#        [     269.97,      210.44,      284.41,      246.73,           0,     0.32113],
#        [     211.15,      201.71,      226.49,      255.99,           0,     0.27017],
#        [     541.03,       216.7,      554.11,      248.63,           0,      0.2591]], dtype=float32)

# %%
all_detections_2 = []

for i in range(len(all_detections)):
    all_detections_2.append(np.hstack((np.ones((len(all_detections[i]), 1))*i, all_detections[i])))

# %%
df2 = pd.DataFrame(np.vstack(all_detections_2))
df2.columns = ["frame", "x1", "y1", "x2", "y2", "cat", "conf"]
df2.head()
# Out:
#    frame          x1          y1          x2          y2  cat      conf
# 0    0.0  293.078369  150.638916  351.447754  321.145355  0.0  0.905575
# 1    0.0  224.198669  185.917297  256.628448  282.383545  0.0  0.842656
# 2    0.0  455.390686  208.806763  483.000183  274.605286  0.0  0.755152
# 3    0.0  587.264526  211.743683  602.703003  246.684662  0.0  0.507081
# 4    0.0  269.969543  210.435547  284.406677  246.733276  0.0  0.321132

# %%
df2.to_csv("ADL-Rundle-6_YOLOv8_detections.csv")

# %% [markdown]
# Use the match and missed tracks arrays to assign tracklet and ground truth to each agent
#
#
# Each Ground Truth Track has an ID the Trackers also have IDs. The IDs should never cross, if they do that is a mismatch error. The agents could possibly keep track of which ground truth IDs are associated (or just the previous ground truth ID. If the new ground truth ID is different, then there is a mismatch error. It's possible that the tracker was wrong the entire time, so we will only conisder mismatch errors between single frames. i.e. if there is a single track switch then we only count it as a single mismatch error.
